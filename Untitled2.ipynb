# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', None)    # Display all rows
pd.set_option('display.max_columns', None) # Display all columns
pd.set_option('display.expand_frame_repr', False) # Prevent wrapping of columns

# %%
xlsx_file_path = '/content/Test sample.xlsx'
csv_file_path = '/content/converted_file.csv'

# %%
df = pd.read_excel(xlsx_file_path, engine='openpyxl')
df.to_csv(csv_file_path, index=False)

# %%
df.head()
# Out:
#     rep_date      tsag_CreatedOnTime  TSAction sales_channel traf_cat_big traf_cat_small traf_cat_type     page_reached_CRM             up_stage                    mid_stage     page_status rejection_group                   sub_stage  is_completed  is_success  is_approved  is_verificated funnel_component
# 0 2022-05-17 2022-05-17 09:11:06.358        20        Mobile      Organic    Google Play          Free  Application Summary  Application Summary  Left on Application Summary       Left page    Not rejected                  z\ no data             1           1            1               1             1-TR
# 1 2022-05-17 2022-05-17 15:10:07.375        17        Mobile   Contextual    Google Play          Paid                  NaN               e-Sign                    Disbursed  Completed page    Not rejected                   Disbursed             1           1            1               1        Disbursed
# 2 2022-05-17 2022-05-17 19:08:06.054         7        Mobile    Affiliate    Cashtap_int          Paid    Bank Verification                  NaN                          NaN             NaN        Rejected  Exists Active Bank Account             0           0            0               0             1-CR
# 3 2022-05-17 2022-05-17 12:52:24.080         7        Mobile      Organic     Vivo store          Free    Bank Verification    Bank Verification           Rejected on Call 1       Left page        Rejected           Active moratorium             1           0            0               0             1-AR
# 4 2022-05-17 2022-05-17 23:00:35.315         3        Mobile    Affiliate      HiCredit           Paid          KYC Details          KYC Details          Left on KYC Details       Left page    Not rejected                  z\ no data             0           0            0               0             1-CR

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121583 entries, 0 to 121582
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   rep_date            121583 non-null  datetime64[ns]
#  1   tsag_CreatedOnTime  121583 non-null  datetime64[ns]
#  2   TSAction            121583 non-null  int64
#  3   sales_channel       121583 non-null  object
#  4   traf_cat_big        121583 non-null  object
#  5   traf_cat_small      121583 non-null  object
#  6   traf_cat_type       121583 non-null  object
#  7   page_reached_CRM    117493 non-null  object
#  8   up_stage            121425 non-null  object
#  9   mid_stage           121425 non-null  object
#  10  page_status         121425 non-null  object
#  11  rejection_group     121583 non-null  object
#  12  sub_stage           121583 non-null  object
#  13  is_completed        121583 non-null  int64
#  14  is_success          121583 non-null  int64
#  15  is_approved         121583 non-null  int64
#  16  is_verificated      121583 non-null  int64
#  17  funnel_component    121583 non-null  object
# dtypes: datetime64[ns](2), int64(5), object(11)
# memory usage: 16.7+ MB

# %%
inspect = ["sales_channel", "traf_cat_big", "traf_cat_small", "traf_cat_type", "page_reached_CRM", "up_stage", "mid_stage", "page_status", "rejection_group", "sub_stage"]

# %%
for column in inspect:
    print(f"Column: {column}")
    print(df[column].value_counts())
# Out:
# Column: sales_channel
# sales_channel
# Mobile    121583
# Name: count, dtype: int64
# Column: traf_cat_big
# traf_cat_big
# Organic          60809
# Affiliate        54729
# Contextual        5103
# z\ no info         526
# Communication      407
# Social Paid          9
# Name: count, dtype: int64
# Column: traf_cat_small
# traf_cat_small
# Google Play          58898
# ValueLeaf            18985
# BuddyLoan            15694
# Vivo store            6063
# Veve                  5696
# Whistle               4120
# Cashtap_int           3673
# inmobi                1270
# HiCredit              1263
# Organic                902
# link2u_int             781
# z\ no info             526
# minoads_int            469
# digitalcashwala        437
# bigfished_int          361
# adsplay                343
# GGSM                   328
# RCS                    248
# globalemedia           242
# HexaWebony             135
# cronbay_int            116
# sms                    110
# Social Donut           100
# MobAvenue               97
# mobiyoung               92
# Admatic                 89
# 19mobi_int              80
# email                   49
# Samsung store           48
# limebrands              46
# veve                    38
# intellectads            34
# biggermobil_int         31
# lilac_int               28
# Advolt agency           27
# cross_sale              22
# Redmedia                19
# afflixtraffic_int       14
# mehimedia_int           13
# Prodigital_int          11
# FaceBook                 9
# PruDigital               9
# candidleands_int         7
# XYAdsagency              7
# Itworks_int              7
# Apex Media               6
# adsplayinternat          4
# affinityveve             4
# dnctrs                   4
# adgloryint_int           4
# ruitimedia_int           2
# googleadwords            2
# Click2Agency             2
# superads_int             2
# Zone media               2
# Tarsan                   2
# vfine_int                2
# xpds                     2
# adzealous                1
# MRND                     1
# Optimedia                1
# ruitomedia_int           1
# adsouch                  1
# eriblabs_int             1
# adyogisventure           1
# optimisemedia            1
# Name: count, dtype: int64
# Column: traf_cat_type
# traf_cat_type
# Free          60785
# Paid          60272
# z\ no info      526
# Name: count, dtype: int64
# Column: page_reached_CRM
# page_reached_CRM
# Bank Verification      56858
# Personal Details       26960
# KYC Details            21728
# e-Nach                  8068
# Application Summary     3717
# e-Sign                   162
# Name: count, dtype: int64
# Column: up_stage
# up_stage
# Bank Verification      49762
# KYC Details            29020
# Personal Details       26952
# Application Summary     7036
# e-Sign                  4633
# e-Nach                  4022
# Name: count, dtype: int64
# Column: mid_stage
# mid_stage
# Rejected on Call 3               33918
# Left on Personal Details         26952
# Left on KYC Details              21540
# Rejected on CRM deduplication     7480
# Rejected on Call 2                6399
# Rejected on Call 1                5943
# Disbursed                         4546
# Rejected on Call 10               4531
# Left on e-Nach                    4022
# Left on Bank Verification         3502
# Left on Application Summary       2505
# Left on e-Sign                      87
# Name: count, dtype: int64
# Column: page_status
# page_status
# Left page         103979
# Completed page     17446
# Name: count, dtype: int64
# Column: rejection_group
# rejection_group
# Not rejected         62917
# Rejected             58480
# Manually rejected      186
# Name: count, dtype: int64
# Column: sub_stage
# sub_stage
# z\ no data                                                           58371
# Scoring Model Reject                                                 18858
# Rejection due to unsecure overdue amount                              7086
# Rejected. Partial data match (ID/Moblie) with other loan receiver     6825
# Rejection due to primary number of accounts                           6038
# New customer rejection due to age                                     5690
# Active moratorium                                                     5566
# Exists Active Bank Account                                            4735
# Disbursed                                                             4546
# Rejection due to primary overdue accounts                             1883
# Bad reference found                                                    459
# Rejected. Exists active agreement                                      423
# Blacklisted Email address                                              349
# Rejection due to product parameters                                    251
# z\ Error: no CRM deduplication                                         214
# Manual rejection                                                       186
# Multiple KYC's evidenced via Credit Bureau                              47
# Rejected (no reason in CRM)                                             18
# Multiple rejections in last 30 days                                     17
# Rejection due to Bureau Ping Error                                       9
# Multiple rejections in last 90 days                                      8
# z\ Error: Unknown                                                        4
# Name: count, dtype: int64
